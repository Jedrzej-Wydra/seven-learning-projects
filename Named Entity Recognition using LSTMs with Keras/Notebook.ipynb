# %% [markdown]
# <img align=center src="https://rhyme.com/assets/img/logo-dark.png"></img>
# <h2 align=center> Named Entity Recognition (NER) using LSTMs with Keras</h2>

# %% [markdown]
# ### Task 1: Project Overview and Import Modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
np.random.seed(0)
plt.style.use("ggplot")

import tensorflow as tf
print('Tensorflow version:', tf.__version__)
print('GPU detected:', tf.config.list_physical_devices('GPU'))
# Out:
# Tensorflow version: 2.1.0
# GPU detected: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Task 2: Load and Explore the NER Dataset

# %% [markdown]
# *Essential info about tagged entities*:
# - geo = Geographical Entity
# - org = Organization
# - per = Person
# - gpe = Geopolitical Entity
# - tim = Time indicator
# - art = Artifact
# - eve = Event
# - nat = Natural Phenomenon

# %%
data = pd.read_csv('ner_dataset.csv', encoding = 'latin1')
data = data.fillna(method = 'ffill')
data.head(20)
# Out:
#      Sentence #           Word  POS    Tag
# 0   Sentence: 1      Thousands  NNS      O
# 1   Sentence: 1             of   IN      O
# 2   Sentence: 1  demonstrators  NNS      O
# 3   Sentence: 1           have  VBP      O
# 4   Sentence: 1        marched  VBN      O
# 5   Sentence: 1        through   IN      O
# 6   Sentence: 1         London  NNP  B-geo
# 7   Sentence: 1             to   TO      O
# 8   Sentence: 1        protest   VB      O
# 9   Sentence: 1            the   DT      O
# 10  Sentence: 1            war   NN      O
# 11  Sentence: 1             in   IN      O
# 12  Sentence: 1           Iraq  NNP  B-geo
# 13  Sentence: 1            and   CC      O
# 14  Sentence: 1         demand   VB      O
# 15  Sentence: 1            the   DT      O
# 16  Sentence: 1     withdrawal   NN      O
# 17  Sentence: 1             of   IN      O
# 18  Sentence: 1        British   JJ  B-gpe
# 19  Sentence: 1         troops  NNS      O

# %%
print("Unique words in corpus:", data['Word'].nunique())
print("Unique words in corpus:", data['Tag'].nunique())
# Out:
# Unique words in corpus: 35178
# Unique words in corpus: 17

# %%
words = list(set(data["Word"].values))
words.append("ENPAD")
num_words = len(words)

# %%
tags = list(set(data["Tag"].values))
num_tags = len(tags)

# %%
num_words, num_tags
# Out:
# (35179, 17)

# %% [markdown]
# ### Task 3: Retrieve Sentences and Corresponsing Tags

# %%
class SentenceGetter(object):
    def __init__(self, data):
        self.n_sent = 1
        self.data = data
        agg_func = lambda s: [(w, p, t) for w, p, t in zip(s["Word"].values.tolist(),
                                                           s["POS"].values.tolist(),
                                                           s["Tag"].values.tolist())]
        self.grouped = self.data.groupby("Sentence #"). apply(agg_func)
        self.sentences = [s for s in self.grouped]

# %%
getter = SentenceGetter(data)
sentences = getter.sentences

# %%
sentences[0]
# Out:
# [('Thousands', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('demonstrators', 'NNS', 'O'),
#  ('have', 'VBP', 'O'),
#  ('marched', 'VBN', 'O'),
#  ('through', 'IN', 'O'),
#  ('London', 'NNP', 'B-geo'),
#  ('to', 'TO', 'O'),
#  ('protest', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('war', 'NN', 'O'),
#  ('in', 'IN', 'O'),
#  ('Iraq', 'NNP', 'B-geo'),
#  ('and', 'CC', 'O'),
#  ('demand', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('withdrawal', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('British', 'JJ', 'B-gpe'),
#  ('troops', 'NNS', 'O'),
#  ('from', 'IN', 'O'),
#  ('that', 'DT', 'O'),
#  ('country', 'NN', 'O'),
#  ('.', '.', 'O')]

# %% [markdown]
# ### Task 4: Define Mappings between Sentences and Tags

# %%
word2idx = {w: i+1 for i, w in enumerate(words)}
tag2idx = {t: i for i, t in enumerate(tags)}

# %%
word2idx
# Out:
# {'insurgency': 1,
#  'centuries': 2,
#  '8,50,000': 3,
#  'clone': 4,
#  'fatally': 5,
#  'Eastern': 6,
#  'massacring': 7,
#  'conglomerate': 8,
#  'Right': 9,
#  'adjourned': 10,
#  '151': 11,
#  'devalued': 12,
#  'suck': 13,
#  'documents': 14,
#  'undermining': 15,
#  'week-long': 16,
#  'diversity': 17,
#  'armor': 18,
#  'intensive': 19,
#  'drone-fired': 20,
#  'liftoff': 21,
#  'Mwenda': 22,
#  'leftists': 23,
#  'Khormato': 24,
#  'perjury': 25,
#  'ODA': 26,
#  'inquiries': 27,
#  'pre-Islamic': 28,
#  'Sena': 29,
#  'Secretariat': 30,
#  'four-nation': 31,
#  'Talabani': 32,
#  'hatched': 33,
#  'unfolded': 34,
#  'inaugurating': 35,
#  'Golo': 36,
#  'Csatia': 37,
#  'stopper': 38,
#  'BJP': 39,
#  'Kochi': 40,
#  'arc': 41,
#  'insulting': 42,
#  'Budny': 43,
#  'Volunteers': 44,
#  'Rau': 45,
#  'slam': 46,
#  'Focusing': 47,
#  'expel': 48,
#  'Mellot': 49,
#  'increased': 50,
#  'cover-up': 51,
#  'Mohcine': 52,
#  'releases': 53,
#  'multi-car': 54,
#  'Candlemas': 55,
#  'Sgorbati': 56,
#  're-deployment': 57,
#  'credit-rating': 58,
#  'https://www.celebritiesforcharity.org/raffles/netraffle_main.cfm': 59,
#  'Substantial': 60,
#  'Kheyal': 61,
#  'Munich': 62,
#  'Ahmet': 63,
#  'Haitian-American': 64,
#  'Shatt': 65,
#  'al-Rashid': 66,
#  'Self-Defense': 67,
#  'Fatma': 68,
#  'two-member': 69,
#  'death-row': 70,
#  'wintery': 71,
#  'overdue': 72,
#  'Dora': 73,
#  'Shengyou': 74,
#  '1852': 75,
#  'Jannati': 76,
#  '210': 77,
#  'Yoweri': 78,
#  'beacons': 79,
#  'Saada': 80,
#  'Clashes': 81,
#  'Dzhennet': 82,
#  'Khalifa': 83,
#  'Upon': 84,
#  'Omollo': 85,
#  'continues': 86,
#  'NIE': 87,
#  'fiercest': 88,
#  'Hollywood': 89,
#  'Hansen': 90,
#  'on-going': 91,
#  'auto': 92,
#  'Lakshman': 93,
#  'sporadically': 94,
#  'Jaca': 95,
#  '35,552': 96,
#  'Navka': 97,
#  'exchanging': 98,
#  'Athens': 99,
#  'rafts': 100,
#  'amid': 101,
#  'Accra': 102,
#  'Boers': 103,
#  'Concentration': 104,
#  'Koufax': 105,
#  'ribbon': 106,
#  'Tursunov': 107,
#  'nights': 108,
#  '94': 109,
#  'cycle': 110,
#  'perching': 111,
#  'regimes': 112,
#  'costliest': 113,
#  'super-combined': 114,
#  'advice': 115,
#  'bombings': 116,
#  'archipelagoes': 117,
#  'Cooperative': 118,
#  'loyalties': 119,
#  'Ogun': 120,
#  'Aleksander': 121,
#  'judgments': 122,
#  'psychologically': 123,
#  'creature': 124,
#  'philosophical': 125,
#  'flagrantly': 126,
#  'repurchased': 127,
#  'Tuberculosis': 128,
#  'fluctuates': 129,
#  'Getty': 130,
#  'PA': 131,
#  'Notre': 132,
#  '1953': 133,
#  'Zvarych': 134,
#  'boded': 135,
#  'importance': 136,
#  'exercised': 137,
#  'spaceship': 138,
#  'voters': 139,
#  'doled': 140,
#  'fact-finding': 141,
#  'contender': 142,
#  'Lytvyn': 143,
#  '10th': 144,
#  'non-EU': 145,
#  'Giuliani': 146,
#  'opening': 147,
#  'scrubbed': 148,
#  'Jessica': 149,
#  'del': 150,
#  'imply': 151,
#  'Vices': 152,
#  'Chadian': 153,
#  'indicted': 154,
#  'then-president': 155,
#  'Dhess': 156,
#  'mentioning': 157,
#  'Tikrit': 158,
#  'taught': 159,
#  'Girls': 160,
#  'absolutely': 161,
#  'accorded': 162,
#  'Kiffa': 163,
#  '0.55': 164,
#  'Boao': 165,
#  'Chongqing': 166,
#  'skullcaps': 167,
#  'types': 168,
#  'newly': 169,
#  'Hadj': 170,
#  'much-needed': 171,
#  '1857': 172,
#  'hanging': 173,
#  'Captain': 174,
#  'Cooper': 175,
#  'Shia': 176,
#  'Nouakchott': 177,
#  '1866': 178,
#  'Employment': 179,
#  'division': 180,
#  'oceanographic': 181,
#  'barcodes': 182,
#  'Blues': 183,
#  'Srinigar': 184,
#  'Thai-Burmese': 185,
#  'loosed': 186,
#  'Ojdanic': 187,
#  'Rösch': 188,
#  'gap': 189,
#  'Grammy-winning': 190,
#  'utilize': 191,
#  'miniaturized': 192,
#  'win': 193,
#  'pigs': 194,
#  'Kony': 195,
#  'poorest': 196,
#  'al-Salami': 197,
#  'interstate': 198,
#  'Expected': 199,
#  'overwhelmed': 200,
#  'Separate': 201,
#  'Olsson': 202,
#  'Salizhan': 203,
#  'Ecumenical': 204,
#  'Equus': 205,
#  'Zigazag': 206,
#  'Georgi': 207,
#  'ran': 208,
#  'Basilica': 209,
#  'compel': 210,
#  'gusting': 211,
#  'shelter': 212,
#  'Herman': 213,
#  'Beerenberg': 214,
#  'stray': 215,
#  'Turkestan': 216,
#  'novel': 217,
#  'intoxicating': 218,
#  'Sooden': 219,
#  'unforgivable': 220,
#  'conserve': 221,
#  'bloodthirsty': 222,
#  'Akihiko': 223,
#  'Helium': 224,
#  'Mario': 225,
#  '22-year-old': 226,
#  'Vista': 227,
#  'Mamoun': 228,
#  'widening': 229,
#  'Mujahedin': 230,
#  'bridle': 231,
#  'Miramax': 232,
#  'Dairy': 233,
#  'Guernsey': 234,
#  'criticizes': 235,
#  'Eyewitnesses': 236,
#  'PRI': 237,
#  'Perth-based': 238,
#  'anti-nuclear': 239,
#  'explosions': 240,
#  'ladders': 241,
#  'Miami-based': 242,
#  'Mariane': 243,
#  'defended': 244,
#  'Holding': 245,
#  'Talib': 246,
#  'sanitation': 247,
#  'UAE': 248,
#  'Croatia': 249,
#  'Rainbow': 250,
#  'long-denied': 251,
#  'Vigilant': 252,
#  'rejoin': 253,
#  'ill-wishers': 254,
#  'Legaspi': 255,
#  'Lashkar-e-Taiba': 256,
#  'subpoena': 257,
#  'quarry': 258,
#  'Akwei': 259,
#  'than': 260,
#  'lighting': 261,
#  'Cobra': 262,
#  'Pontifical': 263,
#  'ballooning': 264,
#  'Rouen': 265,
#  'recharge': 266,
#  'Duggal': 267,
#  'west-southwest': 268,
#  'Dushanbe': 269,
#  'suicides': 270,
#  'single': 271,
#  'activist': 272,
#  'blanketed': 273,
#  'stump': 274,
#  'Ayalon': 275,
#  '1984': 276,
#  'grossly': 277,
#  'whites': 278,
#  'heyday': 279,
#  'Shearer': 280,
#  'Castel': 281,
#  'adamant': 282,
#  'thousand': 283,
#  'Route': 284,
#  'Baez': 285,
#  'Aid': 286,
#  'clan': 287,
#  'Inguri': 288,
#  'Guangzhong': 289,
#  'giants': 290,
#  'Gardena': 291,
#  'QUEZON': 292,
#  'Binh': 293,
#  'Ariana': 294,
#  'Aridi': 295,
#  'Hector': 296,
#  'lynx': 297,
#  'Hamidreza': 298,
#  'extension': 299,
#  'Derg': 300,
#  'ordering': 301,
#  'Klerk': 302,
#  'Sarturday': 303,
#  'conducted': 304,
#  'al-Muasher': 305,
#  'Zimbabwean': 306,
#  'assured': 307,
#  'stars': 308,
#  'Sharipov': 309,
#  'Hu': 310,
#  'publications': 311,
#  'gathering': 312,
#  'Swine': 313,
#  'Duval': 314,
#  'Soyuzcapsule': 315,
#  'fend': 316,
#  'Chaib': 317,
#  'two-million': 318,
#  'Kato': 319,
#  'Abdali': 320,
#  'Abubakar': 321,
#  'brown': 322,
#  'Peshawar': 323,
#  'timely': 324,
#  'freezes': 325,
#  'Kamiya': 326,
#  'Cantarell': 327,
#  'dissidents': 328,
#  'Rashakai': 329,
#  'Airways': 330,
#  'Lanka': 331,
#  'theme-park-like': 332,
#  'Thaksin': 333,
#  'abductee': 334,
#  'prisoners': 335,
#  'redefine': 336,
#  'losing': 337,
#  'Paz': 338,
#  'commissions': 339,
#  'Preaching': 340,
#  'Latvians': 341,
#  'decorating': 342,
#  'Mahmoud': 343,
#  'Momcilo': 344,
#  'Islamists': 345,
#  'Jeep': 346,
#  'Egyptians': 347,
#  'flaws': 348,
#  'coalition': 349,
#  'Hakim': 350,
#  'troops': 351,
#  'Hulya': 352,
#  'chapter': 353,
#  'pastor': 354,
#  'turf': 355,
#  'Spirit': 356,
#  'published': 357,
#  'Alamzai': 358,
#  'Fitch': 359,
#  'Thirty-three': 360,
#  'subsidies': 361,
#  '67': 362,
#  'Ssali': 363,
#  'heroes': 364,
#  'closes': 365,
#  'agitated': 366,
#  'AN': 367,
#  'casino': 368,
#  'Schorr': 369,
#  'western-style': 370,
#  'New~York': 371,
#  'co-defendant': 372,
#  'Leeward': 373,
#  '3,25,000': 374,
#  'grueling': 375,
#  'nationalizations': 376,
#  'statutes': 377,
#  'Ivan': 378,
#  'reconnaissance': 379,
#  'combat-related': 380,
#  'eruptions': 381,
#  'poppies': 382,
#  'Kambakhsh': 383,
#  'tracked': 384,
#  'famously': 385,
#  'Johnson-Sirleaf': 386,
#  'Fossilized': 387,
#  'Waljama': 388,
#  'journals': 389,
#  'covert': 390,
#  'irritated': 391,
#  'vulgar': 392,
#  'Adnan': 393,
#  'gun': 394,
#  '44,000': 395,
#  'euro-denominated': 396,
#  'Amazon.com': 397,
#  'impression': 398,
#  'Maroney': 399,
#  'valuable': 400,
#  'gridlock': 401,
#  'Hobbs': 402,
#  'ex-Beatle': 403,
#  'because': 404,
#  'Madhoun': 405,
#  'Generations': 406,
#  'unwillingness': 407,
#  'guns': 408,
#  'antibiotics': 409,
#  'Winfield': 410,
#  '1,850': 411,
#  'libel': 412,
#  'more-profitable': 413,
#  'sponsor': 414,
#  'Sunni-dominated': 415,
#  'Sahar': 416,
#  'dubs': 417,
#  'non-stop': 418,
#  'Hangzhou': 419,
#  'emigrated': 420,
#  'withdrawn': 421,
#  'Strikes': 422,
#  'Cardinal': 423,
#  'padded': 424,
#  'distanced': 425,
#  '89': 426,
#  'auditing': 427,
#  'Israeli-based': 428,
#  'Henin': 429,
#  'dictates': 430,
#  'Henk': 431,
#  'Ki': 432,
#  'Tickets': 433,
#  'accosted': 434,
#  'cookies': 435,
#  'der': 436,
#  'Okinawa': 437,
#  'du': 438,
#  '1500s': 439,
#  'Mutual': 440,
#  'Patch': 441,
#  'Celebrities': 442,
#  'minivan': 443,
#  'operations': 444,
#  'Gansu': 445,
#  'obligation': 446,
#  'Jeff': 447,
#  'Cairo-based': 448,
#  'Palestinian-Americans': 449,
#  '2011': 450,
#  'Farraj': 451,
#  'NGOs': 452,
#  'Saadat': 453,
#  'Fuzhou': 454,
#  'P.J.': 455,
#  'empowered': 456,
#  '8.7': 457,
#  'synchronize': 458,
#  '68-34': 459,
#  'disqualified': 460,
#  'superba': 461,
#  'Presidential': 462,
#  'Arjangi': 463,
#  'tribe': 464,
#  'Republic-Central': 465,
#  'imam': 466,
#  'Anambra': 467,
#  'Shargudud': 468,
#  'Hib': 469,
#  'EYADEMA': 470,
#  'contest': 471,
#  'revolutionized': 472,
#  'people-to-people': 473,
#  'Darul-Uloom': 474,
#  'Nel': 475,
#  'challenged': 476,
#  'levies': 477,
#  'Kafeel': 478,
#  '710': 479,
#  'private': 480,
#  'rebuilding': 481,
#  'Lara': 482,
#  'glory': 483,
#  'keen': 484,
#  'Ilyas': 485,
#  'rout': 486,
#  'ouster': 487,
#  'fanatic': 488,
#  'judge-and-jury': 489,
#  'party': 490,
#  'Ludlam': 491,
#  'Ion': 492,
#  'Electricidad': 493,
#  'ACCORD': 494,
#  'schedules': 495,
#  'Kapustin': 496,
#  'F-16': 497,
#  'mideast': 498,
#  'Bosch': 499,
#  'Mirza': 500,
#  'drastic': 501,
#  'Chairperson': 502,
#  'Pacheco': 503,
#  'Kouguell': 504,
#  'conquered': 505,
#  'kiosks': 506,
#  'conquest': 507,
#  'Jose': 508,
#  '31-30': 509,
#  'Guys': 510,
#  'Magezi': 511,
#  '70.8': 512,
#  'substantial': 513,
#  'Rheinland-Pfalz': 514,
#  'ministries': 515,
#  'voltage': 516,
#  'Akitani-Bob': 517,
#  'Guangrong': 518,
#  'Giza': 519,
#  'Ulster': 520,
#  'Hkamti': 521,
#  'Alaeddin': 522,
#  'Kabardino-Balkaria': 523,
#  'vested': 524,
#  'Union': 525,
#  'need': 526,
#  'plentiful': 527,
#  'cull': 528,
#  'initiative': 529,
#  '4': 530,
#  'arch-rivals': 531,
#  'TAYA': 532,
#  '4,200': 533,
#  'Netanyahu': 534,
#  'consumer': 535,
#  'Israeli-Hizballah': 536,
#  'approval': 537,
#  'oversight': 538,
#  'hawk': 539,
#  'Colombia': 540,
#  'grew': 541,
#  'Tabaldo': 542,
#  'caters': 543,
#  'discontinued': 544,
#  '1993': 545,
#  'Rowsch': 546,
#  '09-Nov': 547,
#  'Stop': 548,
#  'condition': 549,
#  'nominated': 550,
#  'Faro': 551,
#  'jobless': 552,
#  'Pristina': 553,
#  'Yoram': 554,
#  'Steyn': 555,
#  'logistical': 556,
#  'Fame': 557,
#  'Hispanics': 558,
#  'tax-free': 559,
#  'CPJ': 560,
#  'narrated': 561,
#  'drought': 562,
#  'Baluchis': 563,
#  'Leroy': 564,
#  'withered': 565,
#  'provide': 566,
#  'al-Baghdadi': 567,
#  'Coca-Cola': 568,
#  'then-Hurricane': 569,
#  'Producer': 570,
#  'selective': 571,
#  'Farda': 572,
#  'Tokar': 573,
#  'Mutharika': 574,
#  'Dohuk': 575,
#  'Dinesh': 576,
#  'Chopan': 577,
#  'Al-Shabab': 578,
#  'toxins': 579,
#  'commiserated': 580,
#  'Raad': 581,
#  'plummeted': 582,
#  'batons': 583,
#  'Soomro': 584,
#  'Dutton': 585,
#  'subsidiary': 586,
#  'methods': 587,
#  'Annual': 588,
#  '1.24': 589,
#  'Nazran': 590,
#  'wild': 591,
#  'dominated': 592,
#  'native': 593,
#  'Bodman': 594,
#  'nun': 595,
#  'KEMAKEZA': 596,
#  'expresses': 597,
#  'Goldberg': 598,
#  'Ramadi': 599,
#  'initiation': 600,
#  'candlelight': 601,
#  'anti-capitalist': 602,
#  'Sciences': 603,
#  'paces': 604,
#  'Broncos': 605,
#  'Phuket': 606,
#  'shops': 607,
#  'Kivu': 608,
#  'endeavoured': 609,
#  '10-month-old': 610,
#  'takers': 611,
#  'proud': 612,
#  'Crater': 613,
#  'inspiration': 614,
#  'talent': 615,
#  'dealings': 616,
#  'Kohl': 617,
#  'secessionists': 618,
#  'chapel': 619,
#  'Egebank': 620,
#  'Baixinglou': 621,
#  'cosmetic': 622,
#  'proof': 623,
#  'submerged': 624,
#  'sex': 625,
#  'multi-billion': 626,
#  '11,700': 627,
#  'Hezb-e-Islami': 628,
#  'Bouyeri': 629,
#  'Albania': 630,
#  'snowboard': 631,
#  '616-5': 632,
#  'extradite': 633,
#  'enriched': 634,
#  'non-interference': 635,
#  '1010': 636,
#  'Natasha': 637,
#  'conception': 638,
#  'communion': 639,
#  'shuttles': 640,
#  'regularly': 641,
#  'Meishan': 642,
#  'Al-Said': 643,
#  '13.625': 644,
#  'discovered': 645,
#  'el': 646,
#  'Advanced': 647,
#  'Haneef': 648,
#  '2003': 649,
#  'load': 650,
#  'Salvatrucha': 651,
#  'particulate': 652,
#  'blowtorch': 653,
#  'Gillard': 654,
#  'facilitating': 655,
#  'Provincial': 656,
#  'HARIRI': 657,
#  'aims': 658,
#  'stadiums': 659,
#  'Soltanieh': 660,
#  'Mota': 661,
#  'Entertainment': 662,
#  'mankind': 663,
#  'Tyurin': 664,
#  'Angelina': 665,
#  'preferred': 666,
#  'educating': 667,
#  'tries': 668,
#  'Young-sam': 669,
#  'Am': 670,
#  'regular-season': 671,
#  'helps': 672,
#  'Harbin': 673,
#  '32-year-old': 674,
#  'Graz': 675,
#  'moral': 676,
#  'Major': 677,
#  'beneficial': 678,
#  'Investigators': 679,
#  'busload': 680,
#  'Bagapsh': 681,
#  'sheep-and-cattle': 682,
#  'shortened': 683,
#  'A9': 684,
#  'truckers': 685,
#  'profited': 686,
#  'Mlada': 687,
#  'dormant': 688,
#  'Near-Earth': 689,
#  'tagging': 690,
#  'cricketer-turned-politician': 691,
#  'frenzy': 692,
#  'overborrowing': 693,
#  'Heidelberg': 694,
#  '9.30': 695,
#  'Cock': 696,
#  'hydrocarbons': 697,
#  'Shyrock': 698,
#  'los': 699,
#  'Livestock': 700,
#  'depending': 701,
#  'longed': 702,
#  'U.N.-administered': 703,
#  'MacArthur': 704,
#  'inaccuracies': 705,
#  'Nesnera': 706,
#  'chairmanship': 707,
#  'Artemisian-based': 708,
#  'strictly': 709,
#  'insurgent-held': 710,
#  'slumped': 711,
#  'exchanges': 712,
#  'Hamm': 713,
#  'Rudolf': 714,
#  'Seabees': 715,
#  'motorbikes': 716,
#  'Property': 717,
#  'prediction': 718,
#  'specialize': 719,
#  'Shiekh': 720,
#  'Rawhi': 721,
#  'colonies': 722,
#  'Alu': 723,
#  'collapsed': 724,
#  'floating': 725,
#  'Kononov': 726,
#  're-elected': 727,
#  'Golkar': 728,
#  'republished': 729,
#  'Adult': 730,
#  'Agca': 731,
#  'Fair': 732,
#  'dumped': 733,
#  'gather': 734,
#  'Swedes': 735,
#  'colder-than-normal': 736,
#  'green': 737,
#  'ISRO': 738,
#  'contradicts': 739,
#  'driven': 740,
#  'withdrawing': 741,
#  'thus': 742,
#  'topping': 743,
#  'respirator': 744,
#  'statistician': 745,
#  'campaign': 746,
#  'seven-man': 747,
#  'returns': 748,
#  'bucket': 749,
#  'UNDP': 750,
#  'Ulemas': 751,
#  'NAM': 752,
#  'Soviet-era': 753,
#  'dunking': 754,
#  'Walloons': 755,
#  'Traditionally': 756,
#  'getting': 757,
#  'crops': 758,
#  'la': 759,
#  'prosecutorial': 760,
#  'reinsurer': 761,
#  'Ramzan': 762,
#  'Olympian': 763,
#  'Kong': 764,
#  'addresses': 765,
#  'HKD': 766,
#  'admired': 767,
#  'seek': 768,
#  'Vivanco': 769,
#  'Jufeng': 770,
#  '4x5-kilometer': 771,
#  'preferences': 772,
#  'paddy': 773,
#  'Pro-secular': 774,
#  'loads': 775,
#  'resettlement': 776,
#  'Why': 777,
#  'Tuesday': 778,
#  'hair': 779,
#  'viruses': 780,
#  'Tutor': 781,
#  'emphasis': 782,
#  '44th': 783,
#  'Simone': 784,
#  'one-China': 785,
#  'grandfather': 786,
#  'slurred': 787,
#  'Youssifiyeh': 788,
#  'hearts': 789,
#  'machine': 790,
#  'bed': 791,
#  'rises': 792,
#  'attaché': 793,
#  'Upali': 794,
#  'Uwimana': 795,
#  'horticulture': 796,
#  'circa': 797,
#  'defectors': 798,
#  'defacate': 799,
#  'Rish': 800,
#  'All-Star': 801,
#  'Aero': 802,
#  'exhaustion': 803,
#  'terms': 804,
#  'quieter': 805,
#  'attacking': 806,
#  'flood-damaged': 807,
#  'Meterologists': 808,
#  'Ralia': 809,
#  'Kfar': 810,
#  'Graziano': 811,
#  'Insulza': 812,
#  'Autonomous': 813,
#  'stifle': 814,
#  'Matin': 815,
#  'beg': 816,
#  'Buyat': 817,
#  'inanimate': 818,
#  'Cao': 819,
#  'swimmer': 820,
#  'Barak': 821,
#  'Helios': 822,
#  'revenue': 823,
#  'pyramids': 824,
#  'available': 825,
#  'perceived': 826,
#  'Kufa': 827,
#  'Basutoland': 828,
#  'ideas': 829,
#  'Limit': 830,
#  'snapped': 831,
#  'ACLU': 832,
#  'worst-ever': 833,
#  'Irbil': 834,
#  'Stirling': 835,
#  'al-Tayyah': 836,
#  'Peking': 837,
#  'Pinera': 838,
#  'banjo': 839,
#  'researching': 840,
#  'freest': 841,
#  'blazing': 842,
#  'Adewale': 843,
#  'far-right': 844,
#  'desperate': 845,
#  'Gomaa': 846,
#  'salvage': 847,
#  'cerebral': 848,
#  'exhibited': 849,
#  'Tests': 850,
#  'disputed': 851,
#  'Search': 852,
#  'Perwiz': 853,
#  'renew': 854,
#  'BULL': 855,
#  'mates': 856,
#  'Hayden': 857,
#  '07-Aug': 858,
#  'inaccessible': 859,
#  'PEASANT': 860,
#  'reindeer': 861,
#  'rebels': 862,
#  'try': 863,
#  'Consultative': 864,
#  'cell-phone': 865,
#  'winning': 866,
#  'life-long': 867,
#  'Nikolas': 868,
#  'AB': 869,
#  'deciphering': 870,
#  'denies': 871,
#  'estranged': 872,
#  'Mutahida': 873,
#  'Tan': 874,
#  'jet': 875,
#  'gunfight': 876,
#  'jihad': 877,
#  'linguists': 878,
#  'reasons': 879,
#  'Ruecker': 880,
#  'Prizes': 881,
#  "Ha'aretz": 882,
#  'Annexation': 883,
#  'windows': 884,
#  'hostilities': 885,
#  'Aijalon': 886,
#  'unofficial': 887,
#  'dedication': 888,
#  'redistribution': 889,
#  'tropics': 890,
#  'Piazza': 891,
#  'Millennium': 892,
#  'Segundo': 893,
#  '750': 894,
#  'rejections': 895,
#  '173': 896,
#  'exams': 897,
#  'experimental': 898,
#  'Papahanaumokuakea': 899,
#  'unlimited': 900,
#  'Surgical': 901,
#  'exchange-rate': 902,
#  '454-member': 903,
#  'centerpiece': 904,
#  'near-term': 905,
#  'argument': 906,
#  'Siegler': 907,
#  'likely': 908,
#  'Proceedings': 909,
#  'stadium': 910,
#  'feasibility': 911,
#  'Expectations': 912,
#  'nations': 913,
#  'formulations': 914,
#  'toxicology': 915,
#  'Leumi': 916,
#  'hung': 917,
#  'curator': 918,
#  '57.25': 919,
#  'Aisha': 920,
#  'metric': 921,
#  'ConocoPhillips': 922,
#  'anti-secessionist': 923,
#  'exported': 924,
#  'corner': 925,
#  'patriotic': 926,
#  're-entering': 927,
#  'corals': 928,
#  'career': 929,
#  'arrow': 930,
#  'many': 931,
#  'brief': 932,
#  'Nations-mediated': 933,
#  'lightened': 934,
#  'Raila': 935,
#  'hunting': 936,
#  'dramatically': 937,
#  'marines': 938,
#  'Debalk': 939,
#  'Nay': 940,
#  'gaming-related': 941,
#  'Militias': 942,
#  'beer': 943,
#  'General': 944,
#  'inspecting': 945,
#  'kilometers': 946,
#  'ignore': 947,
#  'Preliminary': 948,
#  '118': 949,
#  'Ignace': 950,
#  'Graham': 951,
#  'reparation': 952,
#  'Intergovernmental': 953,
#  'gently': 954,
#  'Clark': 955,
#  'Odde': 956,
#  'Li': 957,
#  'yams': 958,
#  'biodiversity': 959,
#  'warm': 960,
#  'submitting': 961,
#  'authentic': 962,
#  'MFDC': 963,
#  'actions': 964,
#  'Moscow': 965,
#  'Teachers': 966,
#  'Silver': 967,
#  'blockade': 968,
#  'dissident': 969,
#  'communal': 970,
#  'Confessed': 971,
#  'Catu': 972,
#  'PRODUCTS': 973,
#  'screened': 974,
#  'moderated': 975,
#  'five-time': 976,
#  'Discovery': 977,
#  'Bethelehem': 978,
#  'inter-parliamentary': 979,
#  'Afghan-Pakistan': 980,
#  'Hungary': 981,
#  'KCNA': 982,
#  'subjugation': 983,
#  'serenaded': 984,
#  'insulation': 985,
#  'Eisenman': 986,
#  'animism': 987,
#  'remain': 988,
#  'spaghetti': 989,
#  'Grosjean': 990,
#  'maneuvers': 991,
#  'Xijing': 992,
#  'businesses': 993,
#  'Aussie': 994,
#  'Worker': 995,
#  'tax': 996,
#  'bordered': 997,
#  'Art': 998,
#  'Abed': 999,
#  'smoker': 1000,
#  ...}

# %% [markdown]
# ### Task 5: Padding Input Sentences and Creating Train/Test Splits

# %%
plt.hist([len(s) for s in sentences], bins = 50)
plt.show()

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

max_len = 50

X = [[word2idx[w[0]] for w in s] for s in sentences]
X = pad_sequences(maxlen = max_len, sequences = X, padding = 'post', value = num_words - 1)

y = [[tag2idx[w[2]] for w in s] for s in sentences]
y = pad_sequences(maxlen = max_len, sequences = y, padding = 'post', value = tag2idx["O"])
y = [to_categorical(i, num_classes = num_tags) for i in y]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 1)

# %% [markdown]
# ### Task 6: Build and Compile a Bidirectional LSTM Model

# %%
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import LSTM, Embedding, Dense
from tensorflow.keras.layers import TimeDistributed, SpatialDropout1D, Bidirectional

# %%
input_word = Input(shape = (max_len, ))
model = Embedding(input_dim = num_words, output_dim = max_len, input_length = max_len)(input_word)
model = SpatialDropout1D(0.1)(model)
model = Bidirectional(LSTM(units = 100, return_sequences = True, recurrent_dropout = 0.1))(model)
out = TimeDistributed(Dense(num_tags, activation = 'softmax'))(model)
model = Model(input_word, out)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 50)]              0
# _________________________________________________________________
# embedding (Embedding)        (None, 50, 50)            1758950
# _________________________________________________________________
# spatial_dropout1d (SpatialDr (None, 50, 50)            0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 50, 200)           120800
# _________________________________________________________________
# time_distributed (TimeDistri (None, 50, 17)            3417
# =================================================================
# Total params: 1,883,167
# Trainable params: 1,883,167
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam',
              loss = 'categorical_crossentropy',
             metrics = ['accuracy'])

# %% [markdown]
# ### Task 7: Train the Model

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from livelossplot.tf_keras import PlotLossesCallback

# %%
early_stopping = EarlyStopping(monitor = 'val_accuracy', patience = 1, verbose = 0, mode = 'max', restore_best_weights = False)
callbacks = [PlotLossesCallback(), early_stopping]

history = model.fit(
    x_train, np.array(y_train),
    validation_split = 0.2,
    batch_size = 32,
    epochs = 3,
    verbose = 1,
    callbacks = callbacks
)
# Out:
# Log-loss (cost function):
# training   (min:    0.024, max:    0.032, cur:    0.024)
# validation (min:    0.046, max:    0.049, cur:    0.049)
#
# accuracy:
# training   (min:    0.990, max:    0.992, cur:    0.992)
# validation (min:    0.986, max:    0.986, cur:    0.986)
# 34530/34530 [==============================] - 143s 4ms/sample - loss: 0.0242 - accuracy: 0.9922 - val_loss: 0.0493 - val_accuracy: 0.9858

# %% [markdown]
# ### Task 8: Evaluate Named Entity Recognition Model

# %%
model.evaluate(x_test, np.array(y_test))
# Out:
# 4796/4796 [==============================] - 4s 863us/sample - loss: 0.0508 - accuracy: 0.9855
# [0.05076709948946179, 0.9855421]

# %%
i = np.random.randint(0, x_test.shape[0])
p = model.predict(np.array([x_test[i]]))
p = np.argmax(p, axis = -1)

y_true = np.argmax(np.array(y_test), axis = -1)[i]
print("{:15}{:5}\t {}\n".format("Word", "True", "Pred"))
print("-"*30)
for w, true, pred in zip(x_test[i], y_true, p[0]):
    print("{:15}{}\t{}".format(words[w-1], tags[true], tags[pred]))
# Out:
# Word           True 	 Pred
#
# ------------------------------
# Model          O	O
# education      O	O
# ,              O	O
# social         O	O
# ,              O	O
# and            O	O
# environment    O	O
# programs       O	O
# are            O	O
# underway       O	O
# with           O	O
# support        O	O
# from           O	O
# multilateral   O	O
# development    O	O
# organizations  O	O
# .              O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
# forcibly       O	O
